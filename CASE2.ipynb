# %%
# Show the evolution of total monthly and total annual exports from 
# Brazil (all states and to everywhere) of ‘soybeans’, ‘soybean oil’ and ‘soybean meal’;
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.pylab as plt
import seaborn as sns
import os

# The given file, data_comexstat, was on the csv format file, need to switch it to utf-8 csv file so pandas can read it.
df = pd.read_csv("./data_comexstat.csv")
df.head()
# Out:
#          date product state        country    type   route    tons       usd
# 0  1997-01-01    corn    ES  United States  Import     Sea  44.045  113029.0
# 1  1997-01-01    corn    GO      Argentina  Import  Ground  54.000   36720.0
# 2  1997-01-01    corn    GO        Bolivia  Export  Ground   0.200     180.0
# 3  1997-01-01    corn    GO  United States  Export     Sea   3.488    5688.0
# 4  1997-01-01    corn    MG      Argentina  Import  Ground  27.000   18630.0

# %%
df = pd.read_csv("./teste1.csv")
df.head()
# Out:
#         product        1997        1998        1999        2000        2001  \
# 0  soybean_meal  2744087956  1698538993  1460211197  1609577600  1974379428
# 1   soybean_oil   661073787   926425748   740938821   390116260   492676160
# 2      soybeans  2667731481  2238024116  1528641004  2170208237  2658015802
#
#          2002        2003        2004        2005  ...         2010  \
# 0  2144382337  2544250544  3126504383  2879870683  ...   4731407407
# 1   793830245  1198075794  1388610943  1254939368  ...   1361587916
# 2  2991101775  4194137725  4910348124  5329116960  ...  11079221549
#
#           2011         2012         2013         2014         2015  \
# 0   5697839658   6597674676   6790383352   7001971946   5822471745
# 1   2122241778   2067757895   1367981128   1128359385   1170412768
# 2  16338222484  17595301488  22938712533  23530910108  21085165020
#
#           2016         2017         2018         2019
# 0   5194015474   4974441578   6624510325   5798167207
# ...

# %%
df = pd.read_csv("./sbm.csv")
df.head()
# Out:
#    year  soybean_meal (USD_bi)
# 0  1997             2744087956
# 1  1998             1698538993
# 2  1999             1460211197
# 3  2000             1609577600
# 4  2001             1974379428

# %%
fig, ax = plt.subplots(figsize=(15,6))
sns.barplot(x=df['year'], y=(df['soybean_meal (USD_bi)']), data=df)

ax.set_title("Soybeanmeal Annual exports 1997/2019", fontdict={'fontsize':15})

ax.set_xlabel('YEARS', fontdict={'fontsize':14})

ax.set_ylabel('Soybean_meal (USD, bi)', fontdict={'fontsize':14})
# Out:
# Text(0, 0.5, 'Soybean_meal (USD, bi)')

# %%
df = pd.read_csv("./sboo.csv")
df.head()
# Out:
#    Year  Soybean_oil (USD_bi)
# 0  1997             661073787
# 1  1998             926425748
# 2  1999             740938821
# 3  2000             390116260
# 4  2001             492676160

# %%
fig, ax = plt.subplots(figsize=(15,6))
sns.barplot(x=df['Year'], y=(df['Soybean_oil (USD_bi)']), data=df)

ax.set_title("Soybean oil Annual exports 1997/2019", fontdict={'fontsize':15})

ax.set_xlabel('YEARS', fontdict={'fontsize':14})

ax.set_ylabel('Soybean_oil (USD, bi)', fontdict={'fontsize':14})
# Out:
# Text(0, 0.5, 'Soybean_oil (USD, bi)')

# %%
df = pd.read_csv("./sb.csv")
df.head()
# Out:
#    year  soybeans (USD_bi)
# 0  1997         2667731481
# 1  1998         2238024116
# 2  1999         1528641004
# 3  2000         2170208237
# 4  2001         2658015802

# %%
fig, ax = plt.subplots(figsize=(15,6))
sns.barplot(x=df['year'], y=(df['soybeans (USD_bi)']), data=df)

ax.set_title("Soybeans Annual exports 1997/2019", fontdict={'fontsize':15})

ax.set_xlabel('YEARS', fontdict={'fontsize':14})

ax.set_ylabel('Soybeans (USD, bi)', fontdict={'fontsize':14})
# Out:
# Text(0, 0.5, 'Soybeans (USD, bi)')

# %%
df = pd.read_csv("./monthly1.csv")
df.head()
#soybean meal only
# Out:
#   months       1997       1998       1999       2000       2001       2002  \
# 0    jan  135412302   81430869  116265036   69871762  179381719  145323647
# 1    feb   54252959   56626703   66351898   95646687  119873457   85170361
# 2    mar  154169733  104592643   42558321   91982649  129219689   79607562
# 3    apr  326479371  174751079   82111862  124381207  117371236  122581539
# 4    may  348554397  228350965  168018571  195575323  198441564  111072229
#
#         2003       2004
# 0  184307871  220958903
# 1  118457295  180482137
# 2  120105350  233738371
# 3  127826147  178509640
# 4  223688170  297361085

# %%
# evenly sampled time, monthly
t = df['months']
s1 = df['1997']
s2 = df['1998']
s3 = df['1999']
s4 = df['2000']
s5 = df['2001']
s6 = df['2002']
s7 = df['2003']
s8 = df['2004']


fig, ax = plt.subplots(figsize=(15,6))
plt.plot(t, s1,'r--', label = '1997')
plt.plot(t, s2, 'bs', label = '1998')
plt.plot(t, s3, 'g^', label = '1999') 
plt.plot (t, s4, 'b^', label = '2000')
plt.plot(t, s5, 'y^', label = '2001')
plt.plot(t, s6, 'b--', label = '2002') 
plt.plot(t, s7, 'g--', label = '2003')
plt.plot(t, s8, 'ys', label = '2004')
plt.legend()
ax.set_title("Soybean meal Monthly exports 1997/2004", fontdict={'fontsize':15})
ax.set_xlabel('Months', fontdict={'fontsize':14})
ax.set_ylabel('Soybean meal (USD, bi)', fontdict={'fontsize':14})

plt.show()

# %%
#the values from 1998 1999 2000 2001 are close and it shows stability

# %%
df = pd.read_csv("./monthly2.csv")
df.head()

#soybean oil only

# evenly sampled time, monthly
t = df['months']
s1 = df['1997']
s2 = df['1998']
s3 = df['1999']
s4 = df['2000']
s5 = df['2001']
s6 = df['2002']
s7 = df['2003']
s8 = df['2004']


fig, ax = plt.subplots(figsize=(15,6))
plt.plot(t, s1,'r--', label = '1997')
plt.plot(t, s2, 'bs', label = '1998')
plt.plot(t, s3, 'g^', label = '1999') 
plt.plot (t, s4, 'b^', label = '2000')
plt.plot(t, s5, 'y^', label = '2001')
plt.plot(t, s6, 'b--', label = '2002') 
plt.plot(t, s7, 'g--', label = '2003')
plt.plot(t, s8, 'ys', label = '2004')
plt.legend()
ax.set_title("Soybean oil Monthly exports 1997/2004", fontdict={'fontsize':15})
ax.set_xlabel('Months', fontdict={'fontsize':14})
ax.set_ylabel('Soybean oil (USD, bi)', fontdict={'fontsize':14})

plt.show()

# %%
df = pd.read_csv("./monthly3.csv")
df.head()

#soybean oil only

# evenly sampled time, monthly
t = df['months']
s1 = df['1997']
s2 = df['1998']
s3 = df['1999']
s4 = df['2000']
s5 = df['2001']
s6 = df['2002']
s7 = df['2003']
s8 = df['2004']


fig, ax = plt.subplots(figsize=(15,6))
plt.plot(t, s1,'r--', label = '1997')
plt.plot(t, s2, 'bs', label = '1998')
plt.plot(t, s3, 'g^', label = '1999') 
plt.plot (t, s4, 'b^', label = '2000')
plt.plot(t, s5, 'y^', label = '2001')
plt.plot(t, s6, 'b--', label = '2002') 
plt.plot(t, s7, 'g--', label = '2003')
plt.plot(t, s8, 'ys', label = '2004')
plt.legend()
ax.set_title("Soybeans Monthly exports 1997/2004", fontdict={'fontsize':15})
ax.set_xlabel('Months', fontdict={'fontsize':14})
ax.set_ylabel('Soybeans (USD, bi)', fontdict={'fontsize':14})

plt.show()

# %%
df = pd.read_csv("./monthly4.csv")
df.head()

#soybean meal soybean oil and soybeans total amount monthly from 2005 -2012

# evenly sampled time, monthly
t = df['months']
s1 = df['2005']
s2 = df['2006']
s3 = df['2007']
s4 = df['2008']
s5 = df['2009']
s6 = df['2010']
s7 = df['2011']
s8 = df['2012']


fig, ax = plt.subplots(figsize=(15,6))
plt.plot(t, s1,'r--', label = '2005')
plt.plot(t, s2, 'bs', label = '2006')
plt.plot(t, s3, 'g^', label = '2007') 
plt.plot (t, s4, 'b^', label = '2008')
plt.plot(t, s5, 'y^', label = '2009')
plt.plot(t, s6, 'b--', label = '2010') 
plt.plot(t, s7, 'g--', label = '2011')
plt.plot(t, s8, 'ys', label = '2012')
plt.legend()
ax.set_title("Soybeans/Soybean meal/Soybean oil, Monthly exports 2005/2012", fontdict={'fontsize':15})
ax.set_xlabel('Months', fontdict={'fontsize':14})
ax.set_ylabel('USD, bi', fontdict={'fontsize':14})

plt.show()

# %%
# the curves shows that the revenue involving soy is bigger during apr-aug 
# and falls drastically by the end of the year, a time series with seasonality

# %%
# What are the 3 most important products exported by Brazil in the last 5 years?
# Sugar (40bi), soybean meal (28bi) and soybean(123bi), 2015-2019.

df = pd.read_csv("./last5.csv")
df.head()
# Out:
#         product         2015         2016         2017         2018  \
# 0         sugar   7571738675  10389241712  11376367767   6492958609
# 1          corn   5046782386   4211650182   4831969529   4106308937
# 2  soybean_meal   5822471745   5194015474   4974441578   6624510325
# 3   soybean_oil   1170412768    942036755   1072471727   1050464403
# 4      soybeans  21085165020  19446898310  25747034940  32683442059
#
#           2019  last 5 years
# 0   5117013309   40947320072
# 1   7323600141   25520311175
# 2   5798167207   28413606329
# 3    720352338    4955737991
# 4  24784116897  123746657226

# %%
fig, ax = plt.subplots(figsize=(15,6))
sns.barplot(x=df['product'], y=(df['2015']), data=df)

ax.set_title("Exports 2015", fontdict={'fontsize':15})

ax.set_xlabel('product', fontdict={'fontsize':14})

ax.set_ylabel('USD, 10bi', fontdict={'fontsize':14})
# Out:
# Text(0, 0.5, 'USD, 10bi')

# %%
fig, ax = plt.subplots(figsize=(15,6))
sns.barplot(x=df['product'], y=(df['2016']), data=df)

ax.set_title("Exports 2016", fontdict={'fontsize':15})

ax.set_xlabel('product', fontdict={'fontsize':14})

ax.set_ylabel('USD, 10bi', fontdict={'fontsize':14})
# Out:
# Text(0, 0.5, 'USD, 10bi')

# %%
fig, ax = plt.subplots(figsize=(15,6))
sns.barplot(x=df['product'], y=(df['2017']), data=df)

ax.set_title("Exports 2017", fontdict={'fontsize':15})

ax.set_xlabel('product', fontdict={'fontsize':14})

ax.set_ylabel('USD, 10bi', fontdict={'fontsize':14})


fig, ax = plt.subplots(figsize=(15,6))
sns.barplot(x=df['product'], y=(df['2018']), data=df)

ax.set_title("Exports 2018", fontdict={'fontsize':15})

ax.set_xlabel('product', fontdict={'fontsize':14})

ax.set_ylabel('USD, 10bi', fontdict={'fontsize':14})
# Out:
# Text(0, 0.5, 'USD, 10bi')

# %%
fig, ax = plt.subplots(figsize=(15,6))
sns.barplot(x=df['product'], y=(df['2019']), data=df)

ax.set_title("Exports 2019", fontdict={'fontsize':15})

ax.set_xlabel('product', fontdict={'fontsize':14})

ax.set_ylabel('USD, 10bi', fontdict={'fontsize':14})


fig, ax = plt.subplots(figsize=(15,6))
sns.barplot(x=df['product'], y=(df['last 5 years']), data=df)

ax.set_title("Exports last 5 years", fontdict={'fontsize':15})

ax.set_xlabel('product', fontdict={'fontsize':14})

ax.set_ylabel('USD, 100bi', fontdict={'fontsize':14})
# Out:
# Text(0, 0.5, 'USD, 100bi')

# %%
## What are the main routes through which Brazil have been exporting ‘corn’ in the last few years? 

df = pd.read_csv("./last5r.csv")
df.head()
# Out:
#     route  last 5 years
# 0     Air       7103790
# 1  Ground     821964994
# 2   Other      44135505
# 3   River     966376211
# 4     Sea   23680730675

# %%
# it is easy to see that the sea route represents the more important route, but if we had more elements to see it would be a
# safer way using a code to run check all the elements 
listr=[]
listl=[]


listr=df['route'].values
listl=df['last 5 years'].values

x=0

for i in listl:
    if i>x:
        x=i     
print(x)
#sea route value ~236 bi
# Out:
# 23680730675

# %%
labels = 'Air','Ground','Other','River','Sea'
sizes = listl
explode = (0, 0, 0, 0, 0.1)  

fig1, ax1 = plt.subplots(figsize=(16, 12))
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.2f%%', textprops={'fontsize': 22},
        shadow=True, startangle=8)
ax1.axis('equal') 

plt.show()

# %%
## Are there differences in the relative importance of routes depending on the product? Yes, as shown below.
df= pd.read_csv('./last5rp1.csv')
df.head()
# Out:
#         Product      Air     Ground      Other       River           Sea
# 0         sugar   654763  248925267   20808451    17247288   40659684303
# 1          corn  7103790  821964994   44135505   966376211   23680730675
# 2  soybean_meal  8130101    6333287   30536840       70590   28368535511
# 3   soybean_oil   191057  160844298   25070641     3356822    4766275173
# 4      soybeans   158556  464284623  542343604  3241919462  119497950981

# %%
labels = ['sugar', 'corn', 'soybean meal', 'soybean oil', 'soybeans', 'wheat']
Air = df['Air'].values
Ground = df['Ground'].values
Other = df['Other'].values
River = df['River'].values
#Sea = df['Sea'].values

x = np.arange(len(labels))  
width = 0.35 

fig, ax = plt.subplots(figsize=(16, 12))
rects1 = ax.bar(x - width/2, Air, width, label='Air')
rects2 = ax.bar(x + width/2, Ground, width, label='Ground')
rects3 = ax.bar(x - width/2, Other, width, label='Other')
rects4 = ax.bar(x + width/2, River, width, label='River')
#rects5 = ax.bar(x - width/2, Sea, width, label='Sea')


ax.set_ylabel('USD 100bi', fontsize=18)
ax.set_title('Rout product x Revenue in USD 100bi , 2015/2019',fontsize= 22)
ax.set_xticks(x)
ax.set_xticklabels(labels, fontsize=18)

ax.legend(fontsize=18)





fig.tight_layout()

plt.show()

labels = ['sugar', 'corn', 'soybean meal', 'soybean oil', 'soybeans', 'wheat']
Air = df['Air'].values
Ground = df['Ground'].values
Other = df['Other'].values
River = df['River'].values
Sea = df['Sea'].values

x = np.arange(len(labels))
width = 0.35 

fig, ax = plt.subplots(figsize=(16, 12))
rects1 = ax.bar(x - width/2, Air, width, label='Air')
rects2 = ax.bar(x + width/2, Ground, width, label='Ground')
rects3 = ax.bar(x - width/2, Other, width, label='Other')
rects4 = ax.bar(x + width/2, River, width, label='River')
rects5 = ax.bar(x - width/2, Sea, width, label='Sea')

ax.set_ylabel('USD 100bi', fontsize=18)
ax.set_title('Rout product x Revenue in USD 100bi , 2015/2019',fontsize= 22)
ax.set_xticks(x)
ax.set_xticklabels(labels, fontsize=18)
ax.legend(fontsize=18)


def autolabel(rects):
  
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(15, 3),  
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(rects5)



fig.tight_layout()

plt.show()

# %%
# We can see that relevance of the sea route is huge. If we discard it, the graphs shows that the second most important route
# is the river route for soybeans and corn. Although if we consider the river route for soubean meal, for instance, we will see 
# that there is almost no transportation of soybean meal by the river. Since the soybean meal
# is in pellet form... something to do with humidity perhaps?  



# Which countries have been the most important trade partners for Brazil in terms of ‘corn’ and ‘sugar’ in the last 3 years?

df= pd.read_csv("./csmi.csv")
df.head()
# Out:
#       Country         sugar          corn  (sugar+corn)
# 0        Iran  4.800916e+08  2.822336e+09    3302427878
# 1  Bangladesh  2.063175e+09  5.278790e+08    2591053578
# 2     Algeria  2.176381e+09  2.650813e+08    2441462244
# 3       Egypt  1.010584e+09  1.375065e+09    2385649201
# 4    Malaysia  1.039031e+09  6.963335e+08    1735364581

# %%
# By the dataframe we see that the top 5 more important traders with Brazil in terms of corn and sugar are:
# Iran, Bangladesh,  Algeria,  Egypt and Malaysia.
df= pd.read_csv("./csmi1.csv")

fig, ax = plt.subplots(figsize=(30,12))
sns.barplot(x=df['Country'], y=df['(sugar+corn)'], data=df)

ax.set_title("Exports last 3 years of sugar and corn", fontdict={'fontsize':15})

ax.set_xlabel('Country', fontdict={'fontsize':28})

ax.set_xticklabels(df['Country'], fontsize=22)
ax.set_yticklabels([0,0.5,1,1.5,2.0,2.5,3.0], fontsize=22)

ax.set_ylabel('USD, bi', fontdict={'fontsize':28})
# Out:
# Text(0, 0.5, 'USD, bi')

# %%
# For each of the products in the dataset, show the 5 most important states in terms of exports? MT, PR, SP, RS, GO.
df= pd.read_csv("./datal.csv")
df.head()
# Out:
#   Corn States  Tons of corn Sugar States  Tons of sugar Soybean meal States  \
# 0          MT          4476           SP          19907                  MT
# 1          PR          3744           PR           2043                  PR
# 2          SP          2607           MT            711                  RS
# 3          GO          2883           GO           2748                  SP
# 4          RS          1449           RS            481                  GO
#
#    Tons of soybean meal Soybean oil States  Tons of soybean oil  \
# 0                  3953                 PR                 3542
# 1                  3405                 MT                 2700
# 2                  2749                 SP                 2578
# 3                  1667                 RS                 1424
# 4                  1976                 GO                 1168
#
#   Soybeans States  Tons of soybeans Wheat States  Tons of wheat
# ...

# %%
lists= df['Tons of corn'].values
listr = df['Corn States'].values
labels = listr
sizes = lists
explode = (0.1, 0, 0, 0, 0)  

fig1, ax1 = plt.subplots(figsize=(12, 8))
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.2f%%', textprops={'fontsize': 12},
        shadow=True, startangle=8)
ax1.axis('equal') 



lists = df['Tons of sugar'].values
listr = df['Sugar States'].values
labels = listr
sizes = lists
explode = (0.1, 0, 0, 0, 0)  

fig2, ax2 = plt.subplots(figsize=(12, 8))
ax2.pie(sizes, explode=explode, labels=labels, autopct='%1.2f%%', textprops={'fontsize': 12},
        shadow=True, startangle=8)
ax2.axis('equal') 

plt.show()

lists = df['Tons of soybean meal'].values
listr = df['Soybean meal States'].values
labels = listr
sizes = lists
explode = (0.1, 0, 0, 0, 0)  

fig2, ax2 = plt.subplots(figsize=(12, 8))
ax2.pie(sizes, explode=explode, labels=labels, autopct='%1.2f%%', textprops={'fontsize': 12},
        shadow=True, startangle=8)
ax2.axis('equal') 

plt.show()

lists = df['Tons of soybean oil'].values
listr = df['Soybean oil States'].values
labels = listr
sizes = lists
explode = (0.1, 0, 0, 0, 0)  

fig2, ax2 = plt.subplots(figsize=(12, 8))
ax2.pie(sizes, explode=explode, labels=labels, autopct='%1.2f%%', textprops={'fontsize': 12},
        shadow=True, startangle=8)
ax2.axis('equal') 

plt.show()

lists = df['Tons of soybeans'].values
listr = df['Soybeans States'].values
labels = listr
sizes = lists
explode = (0.1, 0, 0, 0, 0)  

fig2, ax2 = plt.subplots(figsize=(12, 8))
ax2.pie(sizes, explode=explode, labels=labels, autopct='%1.2f%%', textprops={'fontsize': 12},
        shadow=True, startangle=8)
ax2.axis('equal') 

plt.show()

lists = df['Tons of wheat'].values
listr = df['Wheat States'].values
labels = listr
sizes = lists
explode = (0.1, 0, 0, 0, 0)  

fig2, ax2 = plt.subplots(figsize=(12, 8))
ax2.pie(sizes, explode=explode, labels=labels, autopct='%1.2f%%', textprops={'fontsize': 12},
        shadow=True, startangle=8)
ax2.axis('equal') 

plt.show()

# %%
 ##What should be the total brazilian soybeans, soybean_meal, and corn export forecasts, 
   ## in tons, for the next 11 years (2020-2030)?
  ##  We’re mostly interested in the annual forecast.

# %%
df = pd.read_excel("./as.xlsx")

print(df.head())
df.dtypes
# Out:
#      year  tons corn   gdp_china  price_corn
# 0  1997-1        323  560.722750   93.204180
# 1  1998-1        431  604.459124   80.831375
# 2  1999-1        345  651.002477   71.823936
# 3  2000-1        422  706.337687   70.173520
# 4  2001-1        464  765.670053   71.279115
# year           object
# tons corn       int64
# gdp_china     float64
# price_corn    float64
# dtype: object

# %%
data = df
from datetime import datetime
con=data['year']
data['year']=pd.to_datetime(data['year'])
data.set_index('year', inplace=True)
#check datatype of index
data.index
# Out:
# DatetimeIndex(['1997-01-01', '1998-01-01', '1999-01-01', '2000-01-01',
#                '2001-01-01', '2002-01-01', '2003-01-01', '2004-01-01',
#                '2005-01-01', '2006-01-01', '2007-01-01', '2008-01-01',
#                '2009-01-01', '2010-01-01', '2011-01-01', '2012-01-01',
#                '2013-01-01', '2014-01-01', '2015-01-01', '2016-01-01',
#                '2017-01-01', '2018-01-01', '2019-01-01'],
#               dtype='datetime64[ns]', name='year', freq=None)

# %%
ts = data['tons corn']
ts.head()
# Out:
# year
# 1997-01-01    323
# 1998-01-01    431
# 1999-01-01    345
# 2000-01-01    422
# 2001-01-01    464
# Name: tons corn, dtype: int64

# %%
from statsmodels.tsa.stattools import adfuller
def test_stationarity(timeseries):
    
    #Determing rolling statistics
    rolmean = pd.Series(timeseries).rolling(window=12).mean()
    rolstd = pd.Series(timeseries).rolling(window=12).std()
#Plot rolling statistics:
    plt.plot(timeseries, color='blue',label='Original')
    plt.plot(rolmean, color='red', label='Rolling Mean')
    plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show()
    #Perform Dickey-Fuller test:
    print ('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print (dfoutput)

# %%
test_stationarity(ts)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                 -0.777278
# p-value                         0.825706
# #Lags Used                      9.000000
# Number of Observations Used    13.000000
# Critical Value (1%)            -4.068854
# Critical Value (5%)            -3.127149
# Critical Value (10%)           -2.701730
# dtype: float64

# %%
ts = data['gdp_china']
ts.head()
# Out:
# year
# 1997-01-01    560.722750
# 1998-01-01    604.459124
# 1999-01-01    651.002477
# 2000-01-01    706.337687
# 2001-01-01    765.670053
# Name: gdp_china, dtype: float64

# %%
test_stationarity(ts)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  4.469628
# p-value                         1.000000
# #Lags Used                      9.000000
# Number of Observations Used    13.000000
# Critical Value (1%)            -4.068854
# Critical Value (5%)            -3.127149
# Critical Value (10%)           -2.701730
# dtype: float64

# %%
ts = data['price_corn']
test_stationarity(ts)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                 -1.843287
# p-value                         0.359192
# #Lags Used                      1.000000
# Number of Observations Used    21.000000
# Critical Value (1%)            -3.788386
# Critical Value (5%)            -3.013098
# Critical Value (10%)           -2.646397
# dtype: float64

# %%
#"non stationary", tstatisc>critical value, plus the mean keeps growing even when std is minimum.
from IPython.display import Image
Image('corn_price.png')

# the corn price seems to show strong correlation with the tons sell, lower prices would lead to more sells. Although if we look
# to the correlation between gdp and tons the same thing doesnt hold. When China bought the maximum amount of corn 
# (22 tons, 2012) the corn price was ~237 USD. On 2013 China bought 9 tons of corn and the price was even lower. That shows
# that pricextons can not always presents as strong correlation. 

#xtitle tons of corn sold to China

# %%
Image('gdp_China.png')

#xtitle tons of corn sold to China

# %%
from pandas import read_csv
from matplotlib import pyplot
from statsmodels.tsa.ar_model import AutoReg
from sklearn.metrics import mean_squared_error
from math import sqrt
# load dataset
series = read_csv('./now.csv', header=0, index_col=0, parse_dates=True, squeeze=True)
# split dataset
X = series.values
train, test = X[1:len(X)-11], X[len(X)-11:]
# train autoregression
window = 1
model = AutoReg(train, lags=1)
model_fit = model.fit()
coef = model_fit.params
# walk forward over time steps in test
history = train[len(train)-window:]
history = [history[i] for i in range(len(history))]
predictions = list()
for t in range(len(test)):
	length = len(history)
	lag = [history[i] for i in range(length-window,length)]
	yhat = coef[0]
	for d in range(window):
		yhat += coef[d+1] * lag[window-d-1]
	obs = test[t]
	predictions.append(yhat)
	history.append(obs)
	print('predicted=%f, expected=%f' % (yhat, obs))
rmse = sqrt(mean_squared_error(test, predictions))
print('Test RMSE: %.3f' % rmse)
# plot
pyplot.plot(test)
pyplot.plot(predictions, label='prediction', color='red')
plt.suptitle('AR model prediction for tons of corn - 2011/2019')
plt.xlabel('years')
plt.ylabel('tons of corn')
plt.legend()
pyplot.show()
# Out:
# predicted=928.052411, expected=839.000000
# predicted=851.311163, expected=881.000000
# predicted=888.789447, expected=881.000000
# predicted=888.789447, expected=1454.000000
# predicted=1400.100321, expected=1838.000000
# predicted=1742.758918, expected=1328.000000
# predicted=1287.665469, expected=1777.000000
# predicted=1688.326172, expected=1423.000000
# predicted=1372.437778, expected=1487.000000
# predicted=1429.547544, expected=1456.000000
# predicted=1401.885001, expected=2315.000000
# Test RMSE: 410.052

# %%
Image('cornforecast.png')

# %%
# load dataset
series = read_csv('./now1.csv', header=0, index_col=0, parse_dates=True, squeeze=True)
# split dataset
X = series.values
train, test = X[1:len(X)-11], X[len(X)-11:]
# train autoregression
window = 1
model = AutoReg(train, lags=1)
model_fit = model.fit()
coef = model_fit.params
# walk forward over time steps in test
history = train[len(train)-window:]
history = [history[i] for i in range(len(history))]
predictions = list()
for t in range(len(test)):
	length = len(history)
	lag = [history[i] for i in range(length-window,length)]
	yhat = coef[0]
	for d in range(window):
		yhat += coef[d+1] * lag[window-d-1]
	obs = test[t]
	predictions.append(yhat)
	history.append(obs)
	print('predicted=%f, expected=%f' % (yhat, obs))
rmse = sqrt(mean_squared_error(test, predictions))
print('Test RMSE: %.3f' % rmse)
# plot
pyplot.plot(test)
pyplot.plot(predictions, label='prediction', color='red')
plt.suptitle('AR model prediction for tons of soybeans - 2011/2019')
plt.xlabel('years')
plt.ylabel('tons of soybeans')
plt.legend()
pyplot.show()
# Out:
# predicted=1169.070504, expected=1070.000000
# predicted=1111.903289, expected=940.000000
# predicted=988.040990, expected=1002.000000
# predicted=1047.113779, expected=1049.000000
# predicted=1091.894764, expected=1268.000000
# predicted=1300.555098, expected=1429.000000
# predicted=1453.953791, expected=1367.000000
# predicted=1394.881002, expected=1243.000000
# predicted=1276.735425, expected=1438.000000
# predicted=1462.528873, expected=1534.000000
# predicted=1553.996417, expected=1831.000000
# Test RMSE: 143.194

# %%
Image('soybeanforecast.png')

# %%
# load dataset
series = read_csv('./now3.csv', header=0, index_col=0, parse_dates=True, squeeze=True)
# split dataset
X = series.values
train, test = X[1:len(X)-11], X[len(X)-11:]
# train autoregression
window = 1
model = AutoReg(train, lags=1)
model_fit = model.fit()
coef = model_fit.params
# walk forward over time steps in test
history = train[len(train)-window:]
history = [history[i] for i in range(len(history))]
predictions = list()
for t in range(len(test)):
	length = len(history)
	lag = [history[i] for i in range(length-window,length)]
	yhat = coef[0]
	for d in range(window):
		yhat += coef[d+1] * lag[window-d-1]
	obs = test[t]
	predictions.append(yhat)
	history.append(obs)
	print('predicted=%f, expected=%f' % (yhat, obs))
rmse = sqrt(mean_squared_error(test, predictions))
print('Test RMSE: %.3f' % rmse)
# plot
pyplot.plot(test)
pyplot.plot(predictions, label='prediction', color='red')
plt.suptitle('AR model prediction for tons of soybean meal - 2011/2019')
plt.xlabel('years')
plt.ylabel('tons of soybean meal')
plt.legend()
pyplot.show()
# Out:
# predicted=756.180157, expected=719.000000
# predicted=723.471030, expected=769.000000
# predicted=759.024429, expected=772.000000
# predicted=761.157633, expected=827.000000
# predicted=800.266372, expected=834.000000
# predicted=805.243847, expected=934.000000
# predicted=876.350645, expected=1082.000000
# predicted=981.588706, expected=956.000000
# predicted=891.994141, expected=917.000000
# predicted=864.262490, expected=1115.000000
# predicted=1005.053949, expected=1197.000000
# Test RMSE: 123.935

# %%
Image('soybeanmforecast.png')
